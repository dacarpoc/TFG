# %% [markdown]
# # Entrenamiento Preliminar de Modelos
#
# Este script realiza la búsqueda del mejor umbral de ciclos y modelo base para la predicción de roturas de membrana.

# %%
# -*- coding: utf-8 -*-

import os
import warnings
import joblib
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier, HistGradientBoostingClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from imblearn.over_sampling import SMOTE

# Importar configuración y utilidades compartidas
from config import (
    CSV_ENTRENAR, CSV_VALIDAR, MODELO_PRELIMINAR,
    RANDOM_STATE, UMBRALES_CICLOS, THRESHOLDS, MODELOS_DISPONIBLES,
    PESO_FALSOS_POSITIVOS, configurar_logging
)
from utils import crear_derivadas, analizar_membranas, calcular_score_balanceado, evaluar_con_umbral

warnings.filterwarnings('ignore')

# Configurar logger
logger = configurar_logging(__name__)

# %% [markdown]
# ## Configuración Local

# %%
# ================================================================================
# CONFIGURACIÓN LOCAL (sobreescribe config.py si es necesario)
# ================================================================================

# Modelos a evaluar (subconjunto de MODELOS_DISPONIBLES si se desea)
MODELOS_ACTIVOS = MODELOS_DISPONIBLES  # Usar todos los disponibles

# %% [markdown]
# ## Funciones de Modelos

# %%
# ================================================================================
# FUNCIONES DE MODELOS
# ================================================================================

def obtener_modelos():
    """
    Retorna un diccionario con los modelos configurados.
    
    Returns:
        Diccionario {nombre: instancia_modelo}
    """
    modelos = {
        'XGBoost': XGBClassifier(
            n_estimators=200, max_depth=5, learning_rate=0.05,
            scale_pos_weight=15, random_state=RANDOM_STATE, 
            eval_metric='aucpr', n_jobs=-1
        ),
        'LightGBM': LGBMClassifier(
            n_estimators=200, max_depth=5, learning_rate=0.05,
            class_weight='balanced', random_state=RANDOM_STATE, 
            verbose=-1, n_jobs=-1
        ),
        'RandomForest': RandomForestClassifier(
            n_estimators=200, max_depth=8,
            class_weight='balanced_subsample', 
            random_state=RANDOM_STATE, n_jobs=-1
        ),
        'ExtraTrees': ExtraTreesClassifier(
            n_estimators=200, max_depth=10,
            class_weight='balanced_subsample', 
            random_state=RANDOM_STATE, n_jobs=-1
        ),
        'HistGradientBoosting': HistGradientBoostingClassifier(
            max_iter=200, max_depth=5, learning_rate=0.05,
            class_weight='balanced', random_state=RANDOM_STATE
        ),
        'CatBoost': CatBoostClassifier(
            iterations=200, depth=5, learning_rate=0.05,
            auto_class_weights='Balanced', random_state=RANDOM_STATE, 
            verbose=0, allow_writing_files=False
        )
    }
    
    # Filtrar solo modelos activos
    return {k: v for k, v in modelos.items() if k in MODELOS_ACTIVOS}

# %% [markdown]
# ## Carga de Datos

# %%
# ================================================================================
# CARGA DE DATOS
# ================================================================================

logger.info("Cargando datos...")

df_train = pd.read_csv(CSV_ENTRENAR)
df_test = pd.read_csv(CSV_VALIDAR)

# Eliminar columna de índice si existe
for df in [df_train, df_test]:
    if 'Indice' in df.columns:
        df.drop(columns=['Indice'], inplace=True)

logger.info(f"Datos cargados: {len(df_train)} train, {len(df_test)} test")
# Out:
# 2026-02-18 19:15:31 - __main__ - INFO - Cargando datos...
# 2026-02-18 19:15:31 - __main__ - INFO - Datos cargados: 2055 train, 673 test

# %% [markdown]
# ## Ingeniería de Características y Escalado

# %%
# ================================================================================
# INGENIERÍA DE CARACTERÍSTICAS
# ================================================================================

logger.info("Aplicando ingeniería de características...")

df_train_der = crear_derivadas(df_train)
df_test_der = crear_derivadas(df_test)

# Separar variables de objetivo
columnas = [c for c in df_train_der.columns if c != 'Ciclos']

X_train = df_train_der[columnas]
X_test = df_test_der[columnas]
y_train_ciclos = df_train['Ciclos'].values
y_test_ciclos = df_test['Ciclos'].values

# Escalado
logger.info("Escalando variables...")

scaler = StandardScaler()
X_train_esc = pd.DataFrame(scaler.fit_transform(X_train), columns=columnas)
X_test_esc = pd.DataFrame(scaler.transform(X_test), columns=columnas)

logger.info("Preprocesamiento completado.")
# Out:
# 2026-02-18 19:15:36 - __main__ - INFO - Aplicando ingeniería de características...
# 2026-02-18 19:15:36 - __main__ - INFO - Escalando variables...
# 2026-02-18 19:15:36 - __main__ - INFO - Preprocesamiento completado.

# %% [markdown]
# ## Búsqueda del Mejor Umbral de Ciclos

# %%
# ================================================================================
# BÚSQUEDA DEL MEJOR UMBRAL DE CICLOS
# ================================================================================

logger.info("Buscando mejor umbral de ciclos...")
print("="*50)

mejores_por_umbral = {}
modelos = obtener_modelos()

for umbral in UMBRALES_CICLOS:
    y_train_umbral = (y_train_ciclos < umbral).astype(int)
    y_test_umbral = (y_test_ciclos < umbral).astype(int)
    
    # Aplicar SMOTE
    k_neighbors = min(3, y_train_umbral.sum() - 1)
    smote = SMOTE(random_state=RANDOM_STATE, k_neighbors=k_neighbors)
    
    try:
        X_train_res, y_train_bal = smote.fit_resample(X_train_esc, y_train_umbral)
        X_train_bal = pd.DataFrame(X_train_res, columns=columnas)
    except ValueError as e:
        logger.warning(f"SMOTE falló para umbral {umbral}: {e}")
        X_train_bal = X_train_esc
        y_train_bal = y_train_umbral
    
    mejor_umbral = {'score': float('-inf')}
    
    for nombre, clf in modelos.items():
        clf.fit(X_train_bal, y_train_bal)
        y_proba = clf.predict_proba(X_test_esc)[:, 1]
        
        for th in THRESHOLDS:
            result = evaluar_con_umbral(y_test_umbral, y_proba, y_test_ciclos, umbral, th)
            if result:
                score = calcular_score_balanceado(
                    result['pct_membranas'],
                    result['FP'],
                    result['membranas_total'],
                    PESO_FALSOS_POSITIVOS
                )
                
                # --- NUEVO: Imprime cada resultado evaluado ---
                print(f"U={umbral} | Mod={nombre:15} | th={th:.2f} | "
                      f"Membranas={result['membranas_detectadas']}/{result['membranas_total']} | "
                      f"FP={result['FP']} | Score={score:.2f}")

                if score > mejor_umbral['score']:
                    mejor_umbral = {
                        'umbral': umbral,
                        'modelo': nombre,
                        'threshold': th,
                        'score': score,
                        'pct_membranas': result['pct_membranas'],
                        'fp': result['FP'],
                        'resultado': result
                    }
    
    if mejor_umbral['score'] > float('-inf'):
        mejores_por_umbral[umbral] = mejor_umbral
        print(f"\n---> MEJOR PARA UMBRAL {umbral}: {mejor_umbral['modelo']} (Score={mejor_umbral['score']:.2f})\n" + "-"*50)
# Out:
# 2026-02-18 19:21:08 - __main__ - INFO - Buscando mejor umbral de ciclos...
# ==================================================
# U=3 | Mod=XGBoost         | th=0.05 | Membranas=5/5 | FP=170 | Score=-580.00
# U=3 | Mod=XGBoost         | th=0.10 | Membranas=4/5 | FP=102 | Score=-328.00
# U=3 | Mod=XGBoost         | th=0.15 | Membranas=4/5 | FP=71 | Score=-204.00
# U=3 | Mod=XGBoost         | th=0.20 | Membranas=4/5 | FP=58 | Score=-152.00
# U=3 | Mod=XGBoost         | th=0.25 | Membranas=4/5 | FP=48 | Score=-112.00
# U=3 | Mod=XGBoost         | th=0.30 | Membranas=4/5 | FP=38 | Score=-72.00
# U=3 | Mod=XGBoost         | th=0.35 | Membranas=4/5 | FP=34 | Score=-56.00
# U=3 | Mod=XGBoost         | th=0.40 | Membranas=4/5 | FP=26 | Score=-24.00
# U=3 | Mod=XGBoost         | th=0.45 | Membranas=4/5 | FP=22 | Score=-8.00
# U=3 | Mod=XGBoost         | th=0.50 | Membranas=4/5 | FP=20 | Score=0.00
# U=3 | Mod=XGBoost         | th=0.55 | Membranas=4/5 | FP=19 | Score=4.00
# U=3 | Mod=XGBoost         | th=0.60 | Membranas=4/5 | FP=16 | Score=16.00
# U=3 | Mod=XGBoost         | th=0.65 | Membranas=4/5 | FP=15 | Score=20.00
# U=3 | Mod=XGBoost         | th=0.70 | Membranas=4/5 | FP=15 | Score=20.00
# U=3 | Mod=XGBoost         | th=0.75 | Membranas=4/5 | FP=13 | Score=28.00
# U=3 | Mod=XGBoost         | th=0.80 | Membranas=3/5 | FP=12 | Score=12.00
# U=3 | Mod=XGBoost         | th=0.85 | Membranas=3/5 | FP=9 | Score=24.00
# U=3 | Mod=XGBoost         | th=0.90 | Membranas=3/5 | FP=7 | Score=32.00
# U=3 | Mod=XGBoost         | th=0.95 | Membranas=2/5 | FP=6 | Score=16.00
# U=3 | Mod=LightGBM        | th=0.05 | Membranas=5/5 | FP=200 | Score=-700.00
# U=3 | Mod=LightGBM        | th=0.10 | Membranas=5/5 | FP=117 | Score=-368.00
# U=3 | Mod=LightGBM        | th=0.15 | Membranas=5/5 | FP=82 | Score=-228.00
# U=3 | Mod=LightGBM        | th=0.20 | Membranas=4/5 | FP=56 | Score=-144.00
# U=3 | Mod=LightGBM        | th=0.25 | Membranas=4/5 | FP=41 | Score=-84.00
# U=3 | Mod=LightGBM        | th=0.30 | Membranas=4/5 | FP=28 | Score=-32.00
# U=3 | Mod=LightGBM        | th=0.35 | Membranas=4/5 | FP=22 | Score=-8.00
# U=3 | Mod=LightGBM        | th=0.40 | Membranas=4/5 | FP=19 | Score=4.00
# U=3 | Mod=LightGBM        | th=0.45 | Membranas=4/5 | FP=19 | Score=4.00
# U=3 | Mod=LightGBM        | th=0.50 | Membranas=4/5 | FP=18 | Score=8.00
# U=3 | Mod=LightGBM        | th=0.55 | Membranas=4/5 | FP=15 | Score=20.00
# U=3 | Mod=LightGBM        | th=0.60 | Membranas=4/5 | FP=12 | Score=32.00
# U=3 | Mod=LightGBM        | th=0.65 | Membranas=4/5 | FP=10 | Score=40.00
# U=3 | Mod=LightGBM        | th=0.70 | Membranas=4/5 | FP=8 | Score=48.00
# U=3 | Mod=LightGBM        | th=0.75 | Membranas=4/5 | FP=7 | Score=52.00
# U=3 | Mod=LightGBM        | th=0.80 | Membranas=3/5 | FP=6 | Score=36.00
# U=3 | Mod=LightGBM        | th=0.85 | Membranas=2/5 | FP=6 | Score=16.00
# U=3 | Mod=LightGBM        | th=0.90 | Membranas=2/5 | FP=6 | Score=16.00
# U=3 | Mod=LightGBM        | th=0.95 | Membranas=2/5 | FP=3 | Score=28.00
# U=3 | Mod=RandomForest    | th=0.05 | Membranas=5/5 | FP=639 | Score=-2456.00
# U=3 | Mod=RandomForest    | th=0.10 | Membranas=5/5 | FP=523 | Score=-1992.00
# U=3 | Mod=RandomForest    | th=0.15 | Membranas=5/5 | FP=409 | Score=-1536.00
# U=3 | Mod=RandomForest    | th=0.20 | Membranas=5/5 | FP=274 | Score=-996.00
# U=3 | Mod=RandomForest    | th=0.25 | Membranas=5/5 | FP=168 | Score=-572.00
# U=3 | Mod=RandomForest    | th=0.30 | Membranas=5/5 | FP=116 | Score=-364.00
# U=3 | Mod=RandomForest    | th=0.35 | Membranas=3/5 | FP=75 | Score=-240.00
# U=3 | Mod=RandomForest    | th=0.40 | Membranas=3/5 | FP=45 | Score=-120.00
# U=3 | Mod=RandomForest    | th=0.45 | Membranas=3/5 | FP=19 | Score=-16.00
# U=3 | Mod=RandomForest    | th=0.50 | Membranas=3/5 | FP=11 | Score=16.00
# U=3 | Mod=RandomForest    | th=0.55 | Membranas=3/5 | FP=8 | Score=28.00
# U=3 | Mod=RandomForest    | th=0.60 | Membranas=3/5 | FP=5 | Score=40.00
# U=3 | Mod=RandomForest    | th=0.65 | Membranas=2/5 | FP=4 | Score=24.00
# U=3 | Mod=RandomForest    | th=0.70 | Membranas=2/5 | FP=2 | Score=32.00
# U=3 | Mod=RandomForest    | th=0.75 | Membranas=2/5 | FP=0 | Score=40.00
# U=3 | Mod=RandomForest    | th=0.80 | Membranas=0/5 | FP=0 | Score=0.00
# U=3 | Mod=RandomForest    | th=0.85 | Membranas=0/5 | FP=0 | Score=0.00
# U=3 | Mod=RandomForest    | th=0.90 | Membranas=0/5 | FP=0 | Score=0.00
# U=3 | Mod=RandomForest    | th=0.95 | Membranas=0/5 | FP=0 | Score=0.00
# U=3 | Mod=ExtraTrees      | th=0.05 | Membranas=5/5 | FP=658 | Score=-2532.00
# U=3 | Mod=ExtraTrees      | th=0.10 | Membranas=5/5 | FP=658 | Score=-2532.00
# U=3 | Mod=ExtraTrees      | th=0.15 | Membranas=5/5 | FP=614 | Score=-2356.00
# U=3 | Mod=ExtraTrees      | th=0.20 | Membranas=5/5 | FP=533 | Score=-2032.00
# U=3 | Mod=ExtraTrees      | th=0.25 | Membranas=5/5 | FP=358 | Score=-1332.00
# U=3 | Mod=ExtraTrees      | th=0.30 | Membranas=5/5 | FP=184 | Score=-636.00
# U=3 | Mod=ExtraTrees      | th=0.35 | Membranas=5/5 | FP=64 | Score=-156.00
# U=3 | Mod=ExtraTrees      | th=0.40 | Membranas=4/5 | FP=27 | Score=-28.00
# U=3 | Mod=ExtraTrees      | th=0.45 | Membranas=4/5 | FP=14 | Score=24.00
# U=3 | Mod=ExtraTrees      | th=0.50 | Membranas=3/5 | FP=6 | Score=36.00
# U=3 | Mod=ExtraTrees      | th=0.55 | Membranas=3/5 | FP=5 | Score=40.00
# U=3 | Mod=ExtraTrees      | th=0.60 | Membranas=3/5 | FP=2 | Score=52.00
# U=3 | Mod=ExtraTrees      | th=0.65 | Membranas=2/5 | FP=1 | Score=36.00
# U=3 | Mod=ExtraTrees      | th=0.70 | Membranas=0/5 | FP=0 | Score=0.00
# U=3 | Mod=ExtraTrees      | th=0.75 | Membranas=0/5 | FP=0 | Score=0.00
# U=3 | Mod=ExtraTrees      | th=0.80 | Membranas=0/5 | FP=0 | Score=0.00
# U=3 | Mod=ExtraTrees      | th=0.85 | Membranas=0/5 | FP=0 | Score=0.00
# U=3 | Mod=ExtraTrees      | th=0.90 | Membranas=0/5 | FP=0 | Score=0.00
# U=3 | Mod=ExtraTrees      | th=0.95 | Membranas=0/5 | FP=0 | Score=0.00
# U=3 | Mod=HistGradientBoosting | th=0.05 | Membranas=5/5 | FP=214 | Score=-756.00
# U=3 | Mod=HistGradientBoosting | th=0.10 | Membranas=5/5 | FP=114 | Score=-356.00
# U=3 | Mod=HistGradientBoosting | th=0.15 | Membranas=5/5 | FP=71 | Score=-184.00
# U=3 | Mod=HistGradientBoosting | th=0.20 | Membranas=4/5 | FP=48 | Score=-112.00
# U=3 | Mod=HistGradientBoosting | th=0.25 | Membranas=4/5 | FP=37 | Score=-68.00
# U=3 | Mod=HistGradientBoosting | th=0.30 | Membranas=4/5 | FP=25 | Score=-20.00
# U=3 | Mod=HistGradientBoosting | th=0.35 | Membranas=4/5 | FP=21 | Score=-4.00
# U=3 | Mod=HistGradientBoosting | th=0.40 | Membranas=4/5 | FP=16 | Score=16.00
# U=3 | Mod=HistGradientBoosting | th=0.45 | Membranas=4/5 | FP=15 | Score=20.00
# U=3 | Mod=HistGradientBoosting | th=0.50 | Membranas=4/5 | FP=11 | Score=36.00
# U=3 | Mod=HistGradientBoosting | th=0.55 | Membranas=4/5 | FP=9 | Score=44.00
# U=3 | Mod=HistGradientBoosting | th=0.60 | Membranas=4/5 | FP=9 | Score=44.00
# U=3 | Mod=HistGradientBoosting | th=0.65 | Membranas=4/5 | FP=9 | Score=44.00
# U=3 | Mod=HistGradientBoosting | th=0.70 | Membranas=4/5 | FP=8 | Score=48.00
# U=3 | Mod=HistGradientBoosting | th=0.75 | Membranas=4/5 | FP=8 | Score=48.00
# U=3 | Mod=HistGradientBoosting | th=0.80 | Membranas=4/5 | FP=8 | Score=48.00
# U=3 | Mod=HistGradientBoosting | th=0.85 | Membranas=4/5 | FP=6 | Score=56.00
# U=3 | Mod=HistGradientBoosting | th=0.90 | Membranas=3/5 | FP=5 | Score=40.00
# U=3 | Mod=HistGradientBoosting | th=0.95 | Membranas=1/5 | FP=3 | Score=8.00
# U=3 | Mod=CatBoost        | th=0.05 | Membranas=5/5 | FP=387 | Score=-1448.00
# U=3 | Mod=CatBoost        | th=0.10 | Membranas=5/5 | FP=243 | Score=-872.00
# U=3 | Mod=CatBoost        | th=0.15 | Membranas=5/5 | FP=165 | Score=-560.00
# U=3 | Mod=CatBoost        | th=0.20 | Membranas=5/5 | FP=118 | Score=-372.00
# U=3 | Mod=CatBoost        | th=0.25 | Membranas=5/5 | FP=84 | Score=-236.00
# U=3 | Mod=CatBoost        | th=0.30 | Membranas=5/5 | FP=69 | Score=-176.00
# U=3 | Mod=CatBoost        | th=0.35 | Membranas=5/5 | FP=55 | Score=-120.00
# U=3 | Mod=CatBoost        | th=0.40 | Membranas=5/5 | FP=43 | Score=-72.00
# U=3 | Mod=CatBoost        | th=0.45 | Membranas=4/5 | FP=36 | Score=-64.00
# U=3 | Mod=CatBoost        | th=0.50 | Membranas=4/5 | FP=23 | Score=-12.00
# U=3 | Mod=CatBoost        | th=0.55 | Membranas=4/5 | FP=19 | Score=4.00
# U=3 | Mod=CatBoost        | th=0.60 | Membranas=4/5 | FP=12 | Score=32.00
# U=3 | Mod=CatBoost        | th=0.65 | Membranas=4/5 | FP=9 | Score=44.00
# U=3 | Mod=CatBoost        | th=0.70 | Membranas=3/5 | FP=7 | Score=32.00
# U=3 | Mod=CatBoost        | th=0.75 | Membranas=2/5 | FP=6 | Score=16.00
# U=3 | Mod=CatBoost        | th=0.80 | Membranas=2/5 | FP=4 | Score=24.00
# U=3 | Mod=CatBoost        | th=0.85 | Membranas=2/5 | FP=2 | Score=32.00
# U=3 | Mod=CatBoost        | th=0.90 | Membranas=1/5 | FP=1 | Score=16.00
# U=3 | Mod=CatBoost        | th=0.95 | Membranas=1/5 | FP=0 | Score=20.00
#
# ---> MEJOR PARA UMBRAL 3: HistGradientBoosting (Score=56.00)
# --------------------------------------------------
# U=5 | Mod=XGBoost         | th=0.05 | Membranas=5/5 | FP=452 | Score=-1708.00
# U=5 | Mod=XGBoost         | th=0.10 | Membranas=5/5 | FP=355 | Score=-1320.00
# U=5 | Mod=XGBoost         | th=0.15 | Membranas=5/5 | FP=302 | Score=-1108.00
# U=5 | Mod=XGBoost         | th=0.20 | Membranas=5/5 | FP=254 | Score=-916.00
# U=5 | Mod=XGBoost         | th=0.25 | Membranas=5/5 | FP=205 | Score=-720.00
# U=5 | Mod=XGBoost         | th=0.30 | Membranas=5/5 | FP=177 | Score=-608.00
# U=5 | Mod=XGBoost         | th=0.35 | Membranas=5/5 | FP=154 | Score=-516.00
# U=5 | Mod=XGBoost         | th=0.40 | Membranas=5/5 | FP=126 | Score=-404.00
# U=5 | Mod=XGBoost         | th=0.45 | Membranas=5/5 | FP=106 | Score=-324.00
# U=5 | Mod=XGBoost         | th=0.50 | Membranas=5/5 | FP=89 | Score=-256.00
# U=5 | Mod=XGBoost         | th=0.55 | Membranas=5/5 | FP=74 | Score=-196.00
# U=5 | Mod=XGBoost         | th=0.60 | Membranas=5/5 | FP=61 | Score=-144.00
# U=5 | Mod=XGBoost         | th=0.65 | Membranas=5/5 | FP=53 | Score=-112.00
# U=5 | Mod=XGBoost         | th=0.70 | Membranas=5/5 | FP=41 | Score=-64.00
# U=5 | Mod=XGBoost         | th=0.75 | Membranas=5/5 | FP=37 | Score=-48.00
# U=5 | Mod=XGBoost         | th=0.80 | Membranas=5/5 | FP=29 | Score=-16.00
# U=5 | Mod=XGBoost         | th=0.85 | Membranas=5/5 | FP=22 | Score=12.00
# U=5 | Mod=XGBoost         | th=0.90 | Membranas=4/5 | FP=17 | Score=12.00
# U=5 | Mod=XGBoost         | th=0.95 | Membranas=2/5 | FP=7 | Score=12.00
# U=5 | Mod=LightGBM        | th=0.05 | Membranas=5/5 | FP=414 | Score=-1556.00
# U=5 | Mod=LightGBM        | th=0.10 | Membranas=5/5 | FP=300 | Score=-1100.00
# U=5 | Mod=LightGBM        | th=0.15 | Membranas=5/5 | FP=224 | Score=-796.00
# U=5 | Mod=LightGBM        | th=0.20 | Membranas=5/5 | FP=166 | Score=-564.00
# U=5 | Mod=LightGBM        | th=0.25 | Membranas=5/5 | FP=130 | Score=-420.00
# U=5 | Mod=LightGBM        | th=0.30 | Membranas=5/5 | FP=101 | Score=-304.00
# U=5 | Mod=LightGBM        | th=0.35 | Membranas=5/5 | FP=75 | Score=-200.00
# U=5 | Mod=LightGBM        | th=0.40 | Membranas=5/5 | FP=51 | Score=-104.00
# U=5 | Mod=LightGBM        | th=0.45 | Membranas=5/5 | FP=41 | Score=-64.00
# U=5 | Mod=LightGBM        | th=0.50 | Membranas=5/5 | FP=34 | Score=-36.00
# U=5 | Mod=LightGBM        | th=0.55 | Membranas=5/5 | FP=30 | Score=-20.00
# U=5 | Mod=LightGBM        | th=0.60 | Membranas=5/5 | FP=23 | Score=8.00
# U=5 | Mod=LightGBM        | th=0.65 | Membranas=5/5 | FP=17 | Score=32.00
# U=5 | Mod=LightGBM        | th=0.70 | Membranas=4/5 | FP=13 | Score=28.00
# U=5 | Mod=LightGBM        | th=0.75 | Membranas=3/5 | FP=12 | Score=12.00
# U=5 | Mod=LightGBM        | th=0.80 | Membranas=3/5 | FP=10 | Score=20.00
# U=5 | Mod=LightGBM        | th=0.85 | Membranas=2/5 | FP=5 | Score=20.00
# U=5 | Mod=LightGBM        | th=0.90 | Membranas=2/5 | FP=3 | Score=28.00
# U=5 | Mod=LightGBM        | th=0.95 | Membranas=1/5 | FP=2 | Score=12.00
# U=5 | Mod=RandomForest    | th=0.05 | Membranas=5/5 | FP=648 | Score=-2492.00
# U=5 | Mod=RandomForest    | th=0.10 | Membranas=5/5 | FP=622 | Score=-2388.00
# U=5 | Mod=RandomForest    | th=0.15 | Membranas=5/5 | FP=576 | Score=-2204.00
# U=5 | Mod=RandomForest    | th=0.20 | Membranas=5/5 | FP=512 | Score=-1948.00
# U=5 | Mod=RandomForest    | th=0.25 | Membranas=5/5 | FP=399 | Score=-1496.00
# U=5 | Mod=RandomForest    | th=0.30 | Membranas=5/5 | FP=268 | Score=-972.00
# U=5 | Mod=RandomForest    | th=0.35 | Membranas=4/5 | FP=166 | Score=-584.00
# U=5 | Mod=RandomForest    | th=0.40 | Membranas=4/5 | FP=103 | Score=-332.00
# U=5 | Mod=RandomForest    | th=0.45 | Membranas=4/5 | FP=51 | Score=-124.00
# U=5 | Mod=RandomForest    | th=0.50 | Membranas=3/5 | FP=23 | Score=-32.00
# U=5 | Mod=RandomForest    | th=0.55 | Membranas=3/5 | FP=12 | Score=12.00
# U=5 | Mod=RandomForest    | th=0.60 | Membranas=2/5 | FP=4 | Score=24.00
# U=5 | Mod=RandomForest    | th=0.65 | Membranas=2/5 | FP=1 | Score=36.00
# U=5 | Mod=RandomForest    | th=0.70 | Membranas=0/5 | FP=1 | Score=-4.00
# U=5 | Mod=RandomForest    | th=0.75 | Membranas=0/5 | FP=0 | Score=0.00
# U=5 | Mod=RandomForest    | th=0.80 | Membranas=0/5 | FP=0 | Score=0.00
# U=5 | Mod=RandomForest    | th=0.85 | Membranas=0/5 | FP=0 | Score=0.00
# U=5 | Mod=RandomForest    | th=0.90 | Membranas=0/5 | FP=0 | Score=0.00
# U=5 | Mod=RandomForest    | th=0.95 | Membranas=0/5 | FP=0 | Score=0.00
# U=5 | Mod=ExtraTrees      | th=0.05 | Membranas=5/5 | FP=648 | Score=-2492.00
# U=5 | Mod=ExtraTrees      | th=0.10 | Membranas=5/5 | FP=648 | Score=-2492.00
# U=5 | Mod=ExtraTrees      | th=0.15 | Membranas=5/5 | FP=648 | Score=-2492.00
# U=5 | Mod=ExtraTrees      | th=0.20 | Membranas=5/5 | FP=641 | Score=-2464.00
# U=5 | Mod=ExtraTrees      | th=0.25 | Membranas=5/5 | FP=608 | Score=-2332.00
# U=5 | Mod=ExtraTrees      | th=0.30 | Membranas=5/5 | FP=518 | Score=-1972.00
# U=5 | Mod=ExtraTrees      | th=0.35 | Membranas=5/5 | FP=336 | Score=-1244.00
# U=5 | Mod=ExtraTrees      | th=0.40 | Membranas=5/5 | FP=133 | Score=-432.00
# U=5 | Mod=ExtraTrees      | th=0.45 | Membranas=5/5 | FP=36 | Score=-44.00
# U=5 | Mod=ExtraTrees      | th=0.50 | Membranas=4/5 | FP=8 | Score=48.00
# U=5 | Mod=ExtraTrees      | th=0.55 | Membranas=3/5 | FP=5 | Score=40.00
# U=5 | Mod=ExtraTrees      | th=0.60 | Membranas=2/5 | FP=3 | Score=28.00
# U=5 | Mod=ExtraTrees      | th=0.65 | Membranas=2/5 | FP=1 | Score=36.00
# U=5 | Mod=ExtraTrees      | th=0.70 | Membranas=0/5 | FP=0 | Score=0.00
# U=5 | Mod=ExtraTrees      | th=0.75 | Membranas=0/5 | FP=0 | Score=0.00
# U=5 | Mod=ExtraTrees      | th=0.80 | Membranas=0/5 | FP=0 | Score=0.00
# U=5 | Mod=ExtraTrees      | th=0.85 | Membranas=0/5 | FP=0 | Score=0.00
# U=5 | Mod=ExtraTrees      | th=0.90 | Membranas=0/5 | FP=0 | Score=0.00
# U=5 | Mod=ExtraTrees      | th=0.95 | Membranas=0/5 | FP=0 | Score=0.00
# U=5 | Mod=HistGradientBoosting | th=0.05 | Membranas=5/5 | FP=412 | Score=-1548.00
# U=5 | Mod=HistGradientBoosting | th=0.10 | Membranas=5/5 | FP=285 | Score=-1040.00
# U=5 | Mod=HistGradientBoosting | th=0.15 | Membranas=5/5 | FP=206 | Score=-724.00
# U=5 | Mod=HistGradientBoosting | th=0.20 | Membranas=5/5 | FP=161 | Score=-544.00
# U=5 | Mod=HistGradientBoosting | th=0.25 | Membranas=5/5 | FP=126 | Score=-404.00
# U=5 | Mod=HistGradientBoosting | th=0.30 | Membranas=5/5 | FP=88 | Score=-252.00
# U=5 | Mod=HistGradientBoosting | th=0.35 | Membranas=5/5 | FP=64 | Score=-156.00
# U=5 | Mod=HistGradientBoosting | th=0.40 | Membranas=5/5 | FP=50 | Score=-100.00
# U=5 | Mod=HistGradientBoosting | th=0.45 | Membranas=5/5 | FP=37 | Score=-48.00
# U=5 | Mod=HistGradientBoosting | th=0.50 | Membranas=5/5 | FP=28 | Score=-12.00
# U=5 | Mod=HistGradientBoosting | th=0.55 | Membranas=5/5 | FP=23 | Score=8.00
# U=5 | Mod=HistGradientBoosting | th=0.60 | Membranas=5/5 | FP=18 | Score=28.00
# U=5 | Mod=HistGradientBoosting | th=0.65 | Membranas=5/5 | FP=15 | Score=40.00
# U=5 | Mod=HistGradientBoosting | th=0.70 | Membranas=4/5 | FP=9 | Score=44.00
# U=5 | Mod=HistGradientBoosting | th=0.75 | Membranas=3/5 | FP=8 | Score=28.00
# U=5 | Mod=HistGradientBoosting | th=0.80 | Membranas=2/5 | FP=6 | Score=16.00
# U=5 | Mod=HistGradientBoosting | th=0.85 | Membranas=2/5 | FP=3 | Score=28.00
# U=5 | Mod=HistGradientBoosting | th=0.90 | Membranas=2/5 | FP=2 | Score=32.00
# U=5 | Mod=HistGradientBoosting | th=0.95 | Membranas=1/5 | FP=2 | Score=12.00
# U=5 | Mod=CatBoost        | th=0.05 | Membranas=5/5 | FP=517 | Score=-1968.00
# U=5 | Mod=CatBoost        | th=0.10 | Membranas=5/5 | FP=375 | Score=-1400.00
# U=5 | Mod=CatBoost        | th=0.15 | Membranas=5/5 | FP=262 | Score=-948.00
# U=5 | Mod=CatBoost        | th=0.20 | Membranas=5/5 | FP=176 | Score=-604.00
# U=5 | Mod=CatBoost        | th=0.25 | Membranas=5/5 | FP=114 | Score=-356.00
# U=5 | Mod=CatBoost        | th=0.30 | Membranas=5/5 | FP=78 | Score=-212.00
# U=5 | Mod=CatBoost        | th=0.35 | Membranas=5/5 | FP=52 | Score=-108.00
# U=5 | Mod=CatBoost        | th=0.40 | Membranas=5/5 | FP=45 | Score=-80.00
# U=5 | Mod=CatBoost        | th=0.45 | Membranas=5/5 | FP=36 | Score=-44.00
# U=5 | Mod=CatBoost        | th=0.50 | Membranas=5/5 | FP=24 | Score=4.00
# U=5 | Mod=CatBoost        | th=0.55 | Membranas=5/5 | FP=15 | Score=40.00
# U=5 | Mod=CatBoost        | th=0.60 | Membranas=4/5 | FP=13 | Score=28.00
# U=5 | Mod=CatBoost        | th=0.65 | Membranas=4/5 | FP=10 | Score=40.00
# U=5 | Mod=CatBoost        | th=0.70 | Membranas=4/5 | FP=8 | Score=48.00
# U=5 | Mod=CatBoost        | th=0.75 | Membranas=3/5 | FP=4 | Score=44.00
# U=5 | Mod=CatBoost        | th=0.80 | Membranas=3/5 | FP=3 | Score=48.00
# U=5 | Mod=CatBoost        | th=0.85 | Membranas=2/5 | FP=2 | Score=32.00
# U=5 | Mod=CatBoost        | th=0.90 | Membranas=0/5 | FP=1 | Score=-4.00
# U=5 | Mod=CatBoost        | th=0.95 | Membranas=0/5 | FP=0 | Score=0.00
#
# ---> MEJOR PARA UMBRAL 5: ExtraTrees (Score=48.00)
# --------------------------------------------------
# U=7 | Mod=XGBoost         | th=0.05 | Membranas=5/5 | FP=497 | Score=-1888.00
# U=7 | Mod=XGBoost         | th=0.10 | Membranas=5/5 | FP=433 | Score=-1632.00
# U=7 | Mod=XGBoost         | th=0.15 | Membranas=5/5 | FP=382 | Score=-1428.00
# U=7 | Mod=XGBoost         | th=0.20 | Membranas=5/5 | FP=339 | Score=-1256.00
# U=7 | Mod=XGBoost         | th=0.25 | Membranas=5/5 | FP=309 | Score=-1136.00
# U=7 | Mod=XGBoost         | th=0.30 | Membranas=5/5 | FP=276 | Score=-1004.00
# U=7 | Mod=XGBoost         | th=0.35 | Membranas=5/5 | FP=252 | Score=-908.00
# U=7 | Mod=XGBoost         | th=0.40 | Membranas=5/5 | FP=227 | Score=-808.00
# U=7 | Mod=XGBoost         | th=0.45 | Membranas=5/5 | FP=201 | Score=-704.00
# U=7 | Mod=XGBoost         | th=0.50 | Membranas=5/5 | FP=177 | Score=-608.00
# U=7 | Mod=XGBoost         | th=0.55 | Membranas=5/5 | FP=156 | Score=-524.00
# U=7 | Mod=XGBoost         | th=0.60 | Membranas=5/5 | FP=137 | Score=-448.00
# U=7 | Mod=XGBoost         | th=0.65 | Membranas=5/5 | FP=116 | Score=-364.00
# U=7 | Mod=XGBoost         | th=0.70 | Membranas=5/5 | FP=86 | Score=-244.00
# U=7 | Mod=XGBoost         | th=0.75 | Membranas=5/5 | FP=71 | Score=-184.00
# U=7 | Mod=XGBoost         | th=0.80 | Membranas=5/5 | FP=54 | Score=-116.00
# U=7 | Mod=XGBoost         | th=0.85 | Membranas=5/5 | FP=36 | Score=-44.00
# U=7 | Mod=XGBoost         | th=0.90 | Membranas=5/5 | FP=24 | Score=4.00
# U=7 | Mod=XGBoost         | th=0.95 | Membranas=4/5 | FP=12 | Score=32.00
# U=7 | Mod=LightGBM        | th=0.05 | Membranas=5/5 | FP=473 | Score=-1792.00
# U=7 | Mod=LightGBM        | th=0.10 | Membranas=5/5 | FP=331 | Score=-1224.00
# U=7 | Mod=LightGBM        | th=0.15 | Membranas=5/5 | FP=251 | Score=-904.00
# U=7 | Mod=LightGBM        | th=0.20 | Membranas=5/5 | FP=187 | Score=-648.00
# U=7 | Mod=LightGBM        | th=0.25 | Membranas=5/5 | FP=142 | Score=-468.00
# U=7 | Mod=LightGBM        | th=0.30 | Membranas=5/5 | FP=107 | Score=-328.00
# U=7 | Mod=LightGBM        | th=0.35 | Membranas=5/5 | FP=81 | Score=-224.00
# U=7 | Mod=LightGBM        | th=0.40 | Membranas=5/5 | FP=66 | Score=-164.00
# U=7 | Mod=LightGBM        | th=0.45 | Membranas=5/5 | FP=55 | Score=-120.00
# U=7 | Mod=LightGBM        | th=0.50 | Membranas=5/5 | FP=45 | Score=-80.00
# U=7 | Mod=LightGBM        | th=0.55 | Membranas=5/5 | FP=34 | Score=-36.00
# U=7 | Mod=LightGBM        | th=0.60 | Membranas=5/5 | FP=29 | Score=-16.00
# U=7 | Mod=LightGBM        | th=0.65 | Membranas=5/5 | FP=24 | Score=4.00
# U=7 | Mod=LightGBM        | th=0.70 | Membranas=5/5 | FP=17 | Score=32.00
# U=7 | Mod=LightGBM        | th=0.75 | Membranas=4/5 | FP=11 | Score=36.00
# U=7 | Mod=LightGBM        | th=0.80 | Membranas=4/5 | FP=6 | Score=56.00
# U=7 | Mod=LightGBM        | th=0.85 | Membranas=3/5 | FP=2 | Score=52.00
# U=7 | Mod=LightGBM        | th=0.90 | Membranas=2/5 | FP=2 | Score=32.00
# U=7 | Mod=LightGBM        | th=0.95 | Membranas=2/5 | FP=1 | Score=36.00
# U=7 | Mod=RandomForest    | th=0.05 | Membranas=5/5 | FP=637 | Score=-2448.00
# U=7 | Mod=RandomForest    | th=0.10 | Membranas=5/5 | FP=618 | Score=-2372.00
# U=7 | Mod=RandomForest    | th=0.15 | Membranas=5/5 | FP=563 | Score=-2152.00
# U=7 | Mod=RandomForest    | th=0.20 | Membranas=5/5 | FP=495 | Score=-1880.00
# U=7 | Mod=RandomForest    | th=0.25 | Membranas=5/5 | FP=395 | Score=-1480.00
# U=7 | Mod=RandomForest    | th=0.30 | Membranas=5/5 | FP=281 | Score=-1024.00
# U=7 | Mod=RandomForest    | th=0.35 | Membranas=5/5 | FP=195 | Score=-680.00
# U=7 | Mod=RandomForest    | th=0.40 | Membranas=5/5 | FP=115 | Score=-360.00
# U=7 | Mod=RandomForest    | th=0.45 | Membranas=5/5 | FP=53 | Score=-112.00
# U=7 | Mod=RandomForest    | th=0.50 | Membranas=5/5 | FP=25 | Score=0.00
# U=7 | Mod=RandomForest    | th=0.55 | Membranas=3/5 | FP=14 | Score=4.00
# U=7 | Mod=RandomForest    | th=0.60 | Membranas=3/5 | FP=7 | Score=32.00
# U=7 | Mod=RandomForest    | th=0.65 | Membranas=3/5 | FP=3 | Score=48.00
# U=7 | Mod=RandomForest    | th=0.70 | Membranas=1/5 | FP=3 | Score=8.00
# U=7 | Mod=RandomForest    | th=0.75 | Membranas=0/5 | FP=1 | Score=-4.00
# U=7 | Mod=RandomForest    | th=0.80 | Membranas=0/5 | FP=0 | Score=0.00
# U=7 | Mod=RandomForest    | th=0.85 | Membranas=0/5 | FP=0 | Score=0.00
# U=7 | Mod=RandomForest    | th=0.90 | Membranas=0/5 | FP=0 | Score=0.00
# U=7 | Mod=RandomForest    | th=0.95 | Membranas=0/5 | FP=0 | Score=0.00
# U=7 | Mod=ExtraTrees      | th=0.05 | Membranas=5/5 | FP=638 | Score=-2452.00
# U=7 | Mod=ExtraTrees      | th=0.10 | Membranas=5/5 | FP=638 | Score=-2452.00
# U=7 | Mod=ExtraTrees      | th=0.15 | Membranas=5/5 | FP=637 | Score=-2448.00
# U=7 | Mod=ExtraTrees      | th=0.20 | Membranas=5/5 | FP=634 | Score=-2436.00
# U=7 | Mod=ExtraTrees      | th=0.25 | Membranas=5/5 | FP=610 | Score=-2340.00
# U=7 | Mod=ExtraTrees      | th=0.30 | Membranas=5/5 | FP=503 | Score=-1912.00
# U=7 | Mod=ExtraTrees      | th=0.35 | Membranas=5/5 | FP=296 | Score=-1084.00
# U=7 | Mod=ExtraTrees      | th=0.40 | Membranas=5/5 | FP=105 | Score=-320.00
# U=7 | Mod=ExtraTrees      | th=0.45 | Membranas=4/5 | FP=32 | Score=-48.00
# U=7 | Mod=ExtraTrees      | th=0.50 | Membranas=3/5 | FP=9 | Score=24.00
# U=7 | Mod=ExtraTrees      | th=0.55 | Membranas=3/5 | FP=5 | Score=40.00
# U=7 | Mod=ExtraTrees      | th=0.60 | Membranas=3/5 | FP=3 | Score=48.00
# U=7 | Mod=ExtraTrees      | th=0.65 | Membranas=0/5 | FP=1 | Score=-4.00
# U=7 | Mod=ExtraTrees      | th=0.70 | Membranas=0/5 | FP=0 | Score=0.00
# U=7 | Mod=ExtraTrees      | th=0.75 | Membranas=0/5 | FP=0 | Score=0.00
# U=7 | Mod=ExtraTrees      | th=0.80 | Membranas=0/5 | FP=0 | Score=0.00
# U=7 | Mod=ExtraTrees      | th=0.85 | Membranas=0/5 | FP=0 | Score=0.00
# U=7 | Mod=ExtraTrees      | th=0.90 | Membranas=0/5 | FP=0 | Score=0.00
# U=7 | Mod=ExtraTrees      | th=0.95 | Membranas=0/5 | FP=0 | Score=0.00
# U=7 | Mod=HistGradientBoosting | th=0.05 | Membranas=5/5 | FP=449 | Score=-1696.00
# U=7 | Mod=HistGradientBoosting | th=0.10 | Membranas=5/5 | FP=317 | Score=-1168.00
# U=7 | Mod=HistGradientBoosting | th=0.15 | Membranas=5/5 | FP=228 | Score=-812.00
# U=7 | Mod=HistGradientBoosting | th=0.20 | Membranas=5/5 | FP=177 | Score=-608.00
# U=7 | Mod=HistGradientBoosting | th=0.25 | Membranas=5/5 | FP=138 | Score=-452.00
# U=7 | Mod=HistGradientBoosting | th=0.30 | Membranas=5/5 | FP=100 | Score=-300.00
# U=7 | Mod=HistGradientBoosting | th=0.35 | Membranas=5/5 | FP=82 | Score=-228.00
# U=7 | Mod=HistGradientBoosting | th=0.40 | Membranas=5/5 | FP=58 | Score=-132.00
# U=7 | Mod=HistGradientBoosting | th=0.45 | Membranas=5/5 | FP=45 | Score=-80.00
# U=7 | Mod=HistGradientBoosting | th=0.50 | Membranas=5/5 | FP=40 | Score=-60.00
# U=7 | Mod=HistGradientBoosting | th=0.55 | Membranas=5/5 | FP=35 | Score=-40.00
# U=7 | Mod=HistGradientBoosting | th=0.60 | Membranas=5/5 | FP=29 | Score=-16.00
# U=7 | Mod=HistGradientBoosting | th=0.65 | Membranas=5/5 | FP=24 | Score=4.00
# U=7 | Mod=HistGradientBoosting | th=0.70 | Membranas=4/5 | FP=17 | Score=12.00
# U=7 | Mod=HistGradientBoosting | th=0.75 | Membranas=3/5 | FP=10 | Score=20.00
# U=7 | Mod=HistGradientBoosting | th=0.80 | Membranas=3/5 | FP=5 | Score=40.00
# U=7 | Mod=HistGradientBoosting | th=0.85 | Membranas=2/5 | FP=4 | Score=24.00
# U=7 | Mod=HistGradientBoosting | th=0.90 | Membranas=2/5 | FP=1 | Score=36.00
# U=7 | Mod=HistGradientBoosting | th=0.95 | Membranas=2/5 | FP=1 | Score=36.00
# U=7 | Mod=CatBoost        | th=0.05 | Membranas=5/5 | FP=539 | Score=-2056.00
# U=7 | Mod=CatBoost        | th=0.10 | Membranas=5/5 | FP=392 | Score=-1468.00
# U=7 | Mod=CatBoost        | th=0.15 | Membranas=5/5 | FP=266 | Score=-964.00
# U=7 | Mod=CatBoost        | th=0.20 | Membranas=5/5 | FP=172 | Score=-588.00
# U=7 | Mod=CatBoost        | th=0.25 | Membranas=5/5 | FP=127 | Score=-408.00
# U=7 | Mod=CatBoost        | th=0.30 | Membranas=5/5 | FP=88 | Score=-252.00
# U=7 | Mod=CatBoost        | th=0.35 | Membranas=5/5 | FP=56 | Score=-124.00
# U=7 | Mod=CatBoost        | th=0.40 | Membranas=5/5 | FP=41 | Score=-64.00
# U=7 | Mod=CatBoost        | th=0.45 | Membranas=5/5 | FP=31 | Score=-24.00
# U=7 | Mod=CatBoost        | th=0.50 | Membranas=5/5 | FP=22 | Score=12.00
# U=7 | Mod=CatBoost        | th=0.55 | Membranas=4/5 | FP=15 | Score=20.00
# U=7 | Mod=CatBoost        | th=0.60 | Membranas=4/5 | FP=12 | Score=32.00
# U=7 | Mod=CatBoost        | th=0.65 | Membranas=3/5 | FP=8 | Score=28.00
# U=7 | Mod=CatBoost        | th=0.70 | Membranas=3/5 | FP=6 | Score=36.00
# U=7 | Mod=CatBoost        | th=0.75 | Membranas=3/5 | FP=4 | Score=44.00
# U=7 | Mod=CatBoost        | th=0.80 | Membranas=2/5 | FP=1 | Score=36.00
# U=7 | Mod=CatBoost        | th=0.85 | Membranas=0/5 | FP=1 | Score=-4.00
# U=7 | Mod=CatBoost        | th=0.90 | Membranas=0/5 | FP=1 | Score=-4.00
# U=7 | Mod=CatBoost        | th=0.95 | Membranas=0/5 | FP=0 | Score=0.00
#
# ---> MEJOR PARA UMBRAL 7: LightGBM (Score=56.00)
# --------------------------------------------------
# U=9 | Mod=XGBoost         | th=0.05 | Membranas=5/5 | FP=548 | Score=-2092.00
# U=9 | Mod=XGBoost         | th=0.10 | Membranas=5/5 | FP=500 | Score=-1900.00
# U=9 | Mod=XGBoost         | th=0.15 | Membranas=5/5 | FP=464 | Score=-1756.00
# U=9 | Mod=XGBoost         | th=0.20 | Membranas=5/5 | FP=425 | Score=-1600.00
# U=9 | Mod=XGBoost         | th=0.25 | Membranas=5/5 | FP=394 | Score=-1476.00
# U=9 | Mod=XGBoost         | th=0.30 | Membranas=5/5 | FP=362 | Score=-1348.00
# U=9 | Mod=XGBoost         | th=0.35 | Membranas=4/5 | FP=334 | Score=-1256.00
# U=9 | Mod=XGBoost         | th=0.40 | Membranas=4/5 | FP=301 | Score=-1124.00
# U=9 | Mod=XGBoost         | th=0.45 | Membranas=4/5 | FP=279 | Score=-1036.00
# U=9 | Mod=XGBoost         | th=0.50 | Membranas=4/5 | FP=251 | Score=-924.00
# U=9 | Mod=XGBoost         | th=0.55 | Membranas=4/5 | FP=226 | Score=-824.00
# U=9 | Mod=XGBoost         | th=0.60 | Membranas=4/5 | FP=198 | Score=-712.00
# U=9 | Mod=XGBoost         | th=0.65 | Membranas=4/5 | FP=157 | Score=-548.00
# U=9 | Mod=XGBoost         | th=0.70 | Membranas=4/5 | FP=124 | Score=-416.00
# U=9 | Mod=XGBoost         | th=0.75 | Membranas=4/5 | FP=98 | Score=-312.00
# U=9 | Mod=XGBoost         | th=0.80 | Membranas=4/5 | FP=82 | Score=-248.00
# U=9 | Mod=XGBoost         | th=0.85 | Membranas=4/5 | FP=58 | Score=-152.00
# U=9 | Mod=XGBoost         | th=0.90 | Membranas=4/5 | FP=38 | Score=-72.00
# U=9 | Mod=XGBoost         | th=0.95 | Membranas=3/5 | FP=20 | Score=-20.00
# U=9 | Mod=LightGBM        | th=0.05 | Membranas=5/5 | FP=534 | Score=-2036.00
# U=9 | Mod=LightGBM        | th=0.10 | Membranas=5/5 | FP=428 | Score=-1612.00
# U=9 | Mod=LightGBM        | th=0.15 | Membranas=5/5 | FP=351 | Score=-1304.00
# U=9 | Mod=LightGBM        | th=0.20 | Membranas=5/5 | FP=281 | Score=-1024.00
# U=9 | Mod=LightGBM        | th=0.25 | Membranas=5/5 | FP=211 | Score=-744.00
# U=9 | Mod=LightGBM        | th=0.30 | Membranas=5/5 | FP=171 | Score=-584.00
# U=9 | Mod=LightGBM        | th=0.35 | Membranas=5/5 | FP=133 | Score=-432.00
# U=9 | Mod=LightGBM        | th=0.40 | Membranas=5/5 | FP=98 | Score=-292.00
# U=9 | Mod=LightGBM        | th=0.45 | Membranas=5/5 | FP=80 | Score=-220.00
# U=9 | Mod=LightGBM        | th=0.50 | Membranas=5/5 | FP=56 | Score=-124.00
# U=9 | Mod=LightGBM        | th=0.55 | Membranas=5/5 | FP=41 | Score=-64.00
# U=9 | Mod=LightGBM        | th=0.60 | Membranas=5/5 | FP=33 | Score=-32.00
# U=9 | Mod=LightGBM        | th=0.65 | Membranas=5/5 | FP=26 | Score=-4.00
# U=9 | Mod=LightGBM        | th=0.70 | Membranas=5/5 | FP=18 | Score=28.00
# U=9 | Mod=LightGBM        | th=0.75 | Membranas=4/5 | FP=10 | Score=40.00
# U=9 | Mod=LightGBM        | th=0.80 | Membranas=4/5 | FP=6 | Score=56.00
# U=9 | Mod=LightGBM        | th=0.85 | Membranas=4/5 | FP=5 | Score=60.00
# U=9 | Mod=LightGBM        | th=0.90 | Membranas=2/5 | FP=4 | Score=24.00
# U=9 | Mod=LightGBM        | th=0.95 | Membranas=0/5 | FP=2 | Score=-8.00
# U=9 | Mod=RandomForest    | th=0.05 | Membranas=5/5 | FP=628 | Score=-2412.00
# U=9 | Mod=RandomForest    | th=0.10 | Membranas=5/5 | FP=624 | Score=-2396.00
# U=9 | Mod=RandomForest    | th=0.15 | Membranas=5/5 | FP=602 | Score=-2308.00
# U=9 | Mod=RandomForest    | th=0.20 | Membranas=5/5 | FP=528 | Score=-2012.00
# U=9 | Mod=RandomForest    | th=0.25 | Membranas=5/5 | FP=399 | Score=-1496.00
# U=9 | Mod=RandomForest    | th=0.30 | Membranas=5/5 | FP=289 | Score=-1056.00
# U=9 | Mod=RandomForest    | th=0.35 | Membranas=5/5 | FP=191 | Score=-664.00
# U=9 | Mod=RandomForest    | th=0.40 | Membranas=5/5 | FP=104 | Score=-316.00
# U=9 | Mod=RandomForest    | th=0.45 | Membranas=5/5 | FP=59 | Score=-136.00
# U=9 | Mod=RandomForest    | th=0.50 | Membranas=4/5 | FP=25 | Score=-20.00
# U=9 | Mod=RandomForest    | th=0.55 | Membranas=4/5 | FP=13 | Score=28.00
# U=9 | Mod=RandomForest    | th=0.60 | Membranas=3/5 | FP=7 | Score=32.00
# U=9 | Mod=RandomForest    | th=0.65 | Membranas=2/5 | FP=5 | Score=20.00
# U=9 | Mod=RandomForest    | th=0.70 | Membranas=1/5 | FP=3 | Score=8.00
# U=9 | Mod=RandomForest    | th=0.75 | Membranas=1/5 | FP=2 | Score=12.00
# U=9 | Mod=RandomForest    | th=0.80 | Membranas=0/5 | FP=1 | Score=-4.00
# U=9 | Mod=RandomForest    | th=0.85 | Membranas=0/5 | FP=0 | Score=0.00
# U=9 | Mod=RandomForest    | th=0.90 | Membranas=0/5 | FP=0 | Score=0.00
# U=9 | Mod=RandomForest    | th=0.95 | Membranas=0/5 | FP=0 | Score=0.00
# U=9 | Mod=ExtraTrees      | th=0.05 | Membranas=5/5 | FP=628 | Score=-2412.00
# U=9 | Mod=ExtraTrees      | th=0.10 | Membranas=5/5 | FP=628 | Score=-2412.00
# U=9 | Mod=ExtraTrees      | th=0.15 | Membranas=5/5 | FP=626 | Score=-2404.00
# U=9 | Mod=ExtraTrees      | th=0.20 | Membranas=5/5 | FP=621 | Score=-2384.00
# U=9 | Mod=ExtraTrees      | th=0.25 | Membranas=5/5 | FP=607 | Score=-2328.00
# U=9 | Mod=ExtraTrees      | th=0.30 | Membranas=5/5 | FP=542 | Score=-2068.00
# U=9 | Mod=ExtraTrees      | th=0.35 | Membranas=5/5 | FP=359 | Score=-1336.00
# U=9 | Mod=ExtraTrees      | th=0.40 | Membranas=5/5 | FP=158 | Score=-532.00
# U=9 | Mod=ExtraTrees      | th=0.45 | Membranas=5/5 | FP=44 | Score=-76.00
# U=9 | Mod=ExtraTrees      | th=0.50 | Membranas=4/5 | FP=13 | Score=28.00
# U=9 | Mod=ExtraTrees      | th=0.55 | Membranas=3/5 | FP=5 | Score=40.00
# U=9 | Mod=ExtraTrees      | th=0.60 | Membranas=1/5 | FP=3 | Score=8.00
# U=9 | Mod=ExtraTrees      | th=0.65 | Membranas=1/5 | FP=2 | Score=12.00
# U=9 | Mod=ExtraTrees      | th=0.70 | Membranas=0/5 | FP=0 | Score=0.00
# U=9 | Mod=ExtraTrees      | th=0.75 | Membranas=0/5 | FP=0 | Score=0.00
# U=9 | Mod=ExtraTrees      | th=0.80 | Membranas=0/5 | FP=0 | Score=0.00
# U=9 | Mod=ExtraTrees      | th=0.85 | Membranas=0/5 | FP=0 | Score=0.00
# U=9 | Mod=ExtraTrees      | th=0.90 | Membranas=0/5 | FP=0 | Score=0.00
# U=9 | Mod=ExtraTrees      | th=0.95 | Membranas=0/5 | FP=0 | Score=0.00
# U=9 | Mod=HistGradientBoosting | th=0.05 | Membranas=5/5 | FP=543 | Score=-2072.00
# U=9 | Mod=HistGradientBoosting | th=0.10 | Membranas=5/5 | FP=441 | Score=-1664.00
# U=9 | Mod=HistGradientBoosting | th=0.15 | Membranas=5/5 | FP=360 | Score=-1340.00
# U=9 | Mod=HistGradientBoosting | th=0.20 | Membranas=5/5 | FP=291 | Score=-1064.00
# U=9 | Mod=HistGradientBoosting | th=0.25 | Membranas=5/5 | FP=226 | Score=-804.00
# U=9 | Mod=HistGradientBoosting | th=0.30 | Membranas=5/5 | FP=175 | Score=-600.00
# U=9 | Mod=HistGradientBoosting | th=0.35 | Membranas=5/5 | FP=139 | Score=-456.00
# U=9 | Mod=HistGradientBoosting | th=0.40 | Membranas=5/5 | FP=108 | Score=-332.00
# U=9 | Mod=HistGradientBoosting | th=0.45 | Membranas=5/5 | FP=85 | Score=-240.00
# U=9 | Mod=HistGradientBoosting | th=0.50 | Membranas=5/5 | FP=67 | Score=-168.00
# U=9 | Mod=HistGradientBoosting | th=0.55 | Membranas=5/5 | FP=52 | Score=-108.00
# U=9 | Mod=HistGradientBoosting | th=0.60 | Membranas=5/5 | FP=42 | Score=-68.00
# U=9 | Mod=HistGradientBoosting | th=0.65 | Membranas=5/5 | FP=29 | Score=-16.00
# U=9 | Mod=HistGradientBoosting | th=0.70 | Membranas=5/5 | FP=23 | Score=8.00
# U=9 | Mod=HistGradientBoosting | th=0.75 | Membranas=4/5 | FP=16 | Score=16.00
# U=9 | Mod=HistGradientBoosting | th=0.80 | Membranas=4/5 | FP=11 | Score=36.00
# U=9 | Mod=HistGradientBoosting | th=0.85 | Membranas=4/5 | FP=6 | Score=56.00
# U=9 | Mod=HistGradientBoosting | th=0.90 | Membranas=3/5 | FP=4 | Score=44.00
# U=9 | Mod=HistGradientBoosting | th=0.95 | Membranas=0/5 | FP=1 | Score=-4.00
# U=9 | Mod=CatBoost        | th=0.05 | Membranas=5/5 | FP=587 | Score=-2248.00
# U=9 | Mod=CatBoost        | th=0.10 | Membranas=5/5 | FP=453 | Score=-1712.00
# U=9 | Mod=CatBoost        | th=0.15 | Membranas=5/5 | FP=348 | Score=-1292.00
# U=9 | Mod=CatBoost        | th=0.20 | Membranas=5/5 | FP=257 | Score=-928.00
# U=9 | Mod=CatBoost        | th=0.25 | Membranas=5/5 | FP=188 | Score=-652.00
# U=9 | Mod=CatBoost        | th=0.30 | Membranas=5/5 | FP=124 | Score=-396.00
# U=9 | Mod=CatBoost        | th=0.35 | Membranas=5/5 | FP=82 | Score=-228.00
# U=9 | Mod=CatBoost        | th=0.40 | Membranas=5/5 | FP=65 | Score=-160.00
# U=9 | Mod=CatBoost        | th=0.45 | Membranas=5/5 | FP=45 | Score=-80.00
# U=9 | Mod=CatBoost        | th=0.50 | Membranas=5/5 | FP=32 | Score=-28.00
# U=9 | Mod=CatBoost        | th=0.55 | Membranas=5/5 | FP=20 | Score=20.00
# U=9 | Mod=CatBoost        | th=0.60 | Membranas=5/5 | FP=15 | Score=40.00
# U=9 | Mod=CatBoost        | th=0.65 | Membranas=4/5 | FP=12 | Score=32.00
# U=9 | Mod=CatBoost        | th=0.70 | Membranas=3/5 | FP=9 | Score=24.00
# U=9 | Mod=CatBoost        | th=0.75 | Membranas=3/5 | FP=4 | Score=44.00
# U=9 | Mod=CatBoost        | th=0.80 | Membranas=3/5 | FP=3 | Score=48.00
# U=9 | Mod=CatBoost        | th=0.85 | Membranas=1/5 | FP=1 | Score=16.00
# U=9 | Mod=CatBoost        | th=0.90 | Membranas=0/5 | FP=1 | Score=-4.00
# U=9 | Mod=CatBoost        | th=0.95 | Membranas=0/5 | FP=0 | Score=0.00
#
# ---> MEJOR PARA UMBRAL 9: LightGBM (Score=60.00)
# --------------------------------------------------

# %% [markdown]
# ## Selección y Guardado del Mejor Modelo

# %%
# ================================================================================
# SELECCIÓN Y GUARDADO DEL MEJOR MODELO
# ================================================================================

if not mejores_por_umbral:
    raise ValueError("No se encontró ningún umbral válido durante la exploración inicial.")

UMBRAL_OPTIMO = max(mejores_por_umbral.keys(), key=lambda x: mejores_por_umbral[x]['score'])
ganador = mejores_por_umbral[UMBRAL_OPTIMO]
MEJOR_MODELO_NOMBRE = ganador['modelo']

print("="*50)
print(f"🏆 Mejor umbral: {UMBRAL_OPTIMO} ciclos (Score={ganador['score']:.2f})")
print(f"Re-entrenando y guardando ganador: {MEJOR_MODELO_NOMBRE}...")
print("="*50)

# Preparar datos finales con el mejor umbral
y_train_best = (y_train_ciclos < UMBRAL_OPTIMO).astype(int)

# SMOTE de los datos finales
k_v = min(3, y_train_best.sum() - 1)
smote_g = SMOTE(random_state=RANDOM_STATE, k_neighbors=k_v)

try:
    X_tr_g, y_tr_g = smote_g.fit_resample(X_train_esc, y_train_best)
    X_tr_g = pd.DataFrame(X_tr_g, columns=columnas)
except ValueError as e:
    logger.warning(f"SMOTE falló en reentrenamiento: {e}")
    X_tr_g, y_tr_g = X_train_esc, y_train_best

# Re-entrenar modelo ganador
modelo_final = obtener_modelos()[MEJOR_MODELO_NOMBRE]
modelo_final.fit(X_tr_g, y_tr_g)
# Out:
# ==================================================
# 🏆 Mejor umbral: 9 ciclos (Score=60.00)
# Re-entrenando y guardando ganador: LightGBM...
# ==================================================
# LGBMClassifier(class_weight='balanced', learning_rate=0.05, max_depth=5,
#                n_estimators=200, n_jobs=-1, random_state=42, verbose=-1)

# %%
# ================================================================================
# GUARDADO DEL MODELO
# ================================================================================

artifact = {
    'umbral_ciclos': UMBRAL_OPTIMO, 
    'threshold': ganador['threshold'],  # Clave consistente (singular)
    'scaler': scaler,        
    'modelo': modelo_final,
    'feature_cols': list(X_tr_g.columns),
    'nombre_modelo': MEJOR_MODELO_NOMBRE
}

# Crear directorio de salida si no existe
os.makedirs(os.path.dirname(MODELO_PRELIMINAR), exist_ok=True)

# Guardar modelo
joblib.dump(artifact, MODELO_PRELIMINAR)

logger.info(f"Modelo guardado exitosamente en: {MODELO_PRELIMINAR}")
print("\n" + "="*50)
print("ENTRENAMIENTO COMPLETADO")
print("="*50)
# Out:
# 2026-02-18 19:16:40 - __main__ - INFO - Modelo guardado exitosamente en: /Users/daniel/Desktop/TFG/TFG/output/modelo_preliminar.pkl
# ==================================================
# ENTRENAMIENTO COMPLETADO
# ==================================================
